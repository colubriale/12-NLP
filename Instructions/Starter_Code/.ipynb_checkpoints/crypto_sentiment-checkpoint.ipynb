# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer as sid
analyzer = SentimentIntensityAnalyzer()

from newsapi.newsapi_client import NewsApiClient
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Joe\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable

# Load .env enviroment variables
load_dotenv()

# Set News API Key
newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

current_date = pd.Timestamp(datetime.now(), tz="America/New_York").isoformat()
past_date = pd.Timestamp(datetime.now()- timedelta(2), tz="America/New_York").isoformat()

# %%
# Create a newsapi client

# get most relevant 20 headlines per day 
def retrieve_articles(keyword):
    all_headlines = []
    all_dates = []    
    date = datetime.strptime(current_date[:10], "%Y-%m-%d")
    end_date = datetime.strptime(past_date[:10], "%Y-%m-%d")
    print(f"Fetching news about '{keyword}'")
    print("*" * 30)
    while date > end_date:
        print(f"retrieving news from: {date}")
        articles = newsapi.get_everything(
            q=keyword,
            from_param=str(date)[:30],
            to=str(date)[:30],
            language="en",
            sort_by="relevancy",
            page=1,
            page_size=100
            )
        
        date = date - timedelta(days=1)
        
    return articles

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_news = retrieve_articles("Bitcoin")
# Out:
# Fetching news about 'Bitcoin'
# ******************************
# retrieving news from: 2021-09-24 00:00:00
# retrieving news from: 2021-09-23 00:00:00

# %%
btc_news["articles"][1]["content"]
# Out:
# 'Posted \r\nTwitter will now allow people to tip their favorite content creators with bitcoin and it will test new ways to help users have a safer experience on the social media app, the company said on… [+44 chars]'

# %%
# Fetch the Ethereum news articles
eth_news = retrieve_articles("Ethereum")
# Out:
# Fetching news about 'Ethereum'
# ******************************
# retrieving news from: 2021-09-24 00:00:00
# retrieving news from: 2021-09-23 00:00:00

# %%
eth_news["articles"][1]["content"]
# Out:
# 'Paolo Ardoino was on the front lines of one of the largest cryptocurrency heists of all time. He was flooded with calls and messages in August alerting him to a breach at Poly Network, a platform whe… [+2585 chars]'

# %%
def get_articles(articles) :

    article_body = []

    for i in range(0, len(articles["articles"])) :
        # If we wanted title we would use the following but we will use Content in this case
        #headlines.append(articles["articles"][i]["title"])
        article_body.append(articles["articles"][i]["content"])     

    return article_body

# %%
# def articles_sentiment_summarizer(articles):
#     # get the sentiment for every article then store it in a list
#     article_sentiment_score = []

#     for article in articles:
#         try:
#             article_sentiment_score.append(analyzer.polarity_scores(article))
#         except Exception as e:
#             print(e)
        
#     return article_sentiment_score

# %%
# Create the Bitcoin sentiment scores DataFrame
def articles_sentiment_summarizer(articles):
    # get the sentiment for every article then store it in a list
    article_sentiment_row = []
    
    for article in articles:
        try:

            article_sentiment_score= analyzer.polarity_scores(article)
            compound_score = article_sentiment_score["compound"]
            neg_score = article_sentiment_score["neg"]
            neu_score = article_sentiment_score["neu"]
            pos_score = article_sentiment_score["pos"]
            article_sentiment_row.append({"Compound": compound_score,
                                            "Negative": neg_score,
                                            "Neutral": neu_score ,
                                            "Positive": pos_score,
                                            "Text": article
                                         })

            
        except Exception as e:
            print(e)
            
    return article_sentiment_row

# %%
# Create A BTC Dataframe of the sentiment results
btc_news_articles = get_articles(btc_news)
btc_sentiment = articles_sentiment_summarizer(btc_news_articles)

# Create a DataFrame of the results
df_btc_sentiment = pd.DataFrame(btc_sentiment)
df_btc_sentiment.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1    0.8555     0.000    0.760     0.240
# 2    0.3804     0.000    0.933     0.067
# 3   -0.0418     0.086    0.835     0.079
# 4    0.2263     0.000    0.940     0.060
#
#                                                 Text
# 0  Four months after Twitter first introduced in-...
# 1  Posted \r\nTwitter will now allow people to ti...
# 2  Twitter will soon make Spaces even more promin...
# 3  The Fine Print: The following comments are own...
# 4  The Twitter app is seen on a smartphone in thi...

# %%
df_btc_sentiment.describe()
# Out:
#          Compound    Negative     Neutral    Positive
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.220863    0.026330    0.894430    0.079250
# std      0.384585    0.051624    0.086137    0.074696
# min     -0.900100    0.000000    0.624000    0.000000
# 25%      0.000000    0.000000    0.843250    0.000000
# 50%      0.300800    0.000000    0.916000    0.070000
# 75%      0.475725    0.038750    0.948000    0.117500
# max      0.932500    0.261000    1.000000    0.366000

# %%
# Create the Ethereum sentiment scores DataFrame
# Fetch the Etherium news articles
eth_news_articles = get_articles(eth_news)


# Calculate the Etherium Sentiment
eth_sentiment = articles_sentiment_summarizer(eth_news_articles)

# Create a DataFrame of the results
df_eth_sentiment = pd.DataFrame(eth_sentiment)
df_eth_sentiment.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.0516     0.128    0.778     0.094
# 1    0.0000     0.000    1.000     0.000
# 2    0.8402     0.000    0.714     0.286
# 3    0.7269     0.000    0.803     0.197
# 4    0.0000     0.000    1.000     0.000
#
#                                                 Text
# 0  crypto coins circle\r\nNurphoto\r\nThe smaller...
# 1  Paolo Ardoino was on the front lines of one of...
# 2  What happened\r\nPopular cryptocurrency Dogeco...
# 3  Starting next month, select users will begin t...
# 4  The personality behind the NFT Twitter account...

# %%
df_eth_sentiment.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  99.000000  99.000000  99.000000  99.000000
# mean    0.214654   0.026374   0.896949   0.076707
# std     0.372819   0.059891   0.086846   0.070420
# min    -0.904200   0.000000   0.672000   0.000000
# 25%     0.000000   0.000000   0.836500   0.000000
# 50%     0.202300   0.000000   0.912000   0.075000
# 75%     0.526700   0.000000   0.985500   0.129000
# max     0.840200   0.328000   1.000000   0.286000

# %% [markdown]
# # Describe the Bitcoin Sentiment
#
# Looking at the Bitcoin Sentiment mean of 100 articles Bitcoin 89.4% of the artles are Neutral 7.9% are positive and 2.6% are negative.
# However overall the Compound result tells use that the artles are 22% on the positive scale
#
# 	Compound	Negative	Neutral	Positive
# count	100.000000	100.000000	100.000000	100.000000
# mean	0.220863	0.026330	0.894430	0.079250

# %%
# Describe the Ethereum Sentiment

Etherium is almost identical to Bitcoin in sentiment. Looking at the Ethereum Sentiment mean of 99 Ethereum articles 89.6% of the artles are Neutral 7.8% are positive and 2.6% are negative. 
However overall the Compound result tells use that the artles are 21.4% on the positive scale

	Compound	Negative	Neutral	Positive
count	99.000000	99.000000	99.000000	99.000000
mean	0.214654	0.026374	0.896949	0.076707

# %% [raw]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = stopwords.words('english')


# Expand the default stopwords list if necessary

sw.append('badwordz')
print(sw)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'badwordz']

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
   
    # Create a tokenized list of the words
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    # and  Remove the stop words # I use "not in sw]"
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc_tokens = tokenizer(btc_news_articles[1])
btc_tokens
# Out:
# ['posted',
#  'twitter',
#  'allow',
#  'people',
#  'tip',
#  'favorite',
#  'content',
#  'creator',
#  'bitcoin',
#  'test',
#  'new',
#  'way',
#  'help',
#  'user',
#  'safer',
#  'experience',
#  'social',
#  'medium',
#  'app',
#  'company',
#  'said',
#  'char']

# %%
df_btc_sentiment.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1    0.8555     0.000    0.760     0.240
# 2    0.3804     0.000    0.933     0.067
# 3   -0.0418     0.086    0.835     0.079
# 4    0.2263     0.000    0.940     0.060
#
#                                                 Text
# 0  Four months after Twitter first introduced in-...
# 1  Posted \r\nTwitter will now allow people to ti...
# 2  Twitter will soon make Spaces even more promin...
# 3  The Fine Print: The following comments are own...
# 4  The Twitter app is seen on a smartphone in thi...

# %%
# Create a new tokens column for Bitcoin
tokens =[]
for i in range(len(df_btc_sentiment)) :
    article_tokens = tokenizer(df_btc_sentiment["Text"][i])
    tokens.append(article_tokens)

df_btc_sentiment["tokens"] = tokens     
df_btc_sentiment.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000     0.000    1.000     0.000
# 1    0.8555     0.000    0.760     0.240
# 2    0.3804     0.000    0.933     0.067
# 3   -0.0418     0.086    0.835     0.079
# 4    0.2263     0.000    0.940     0.060
#
#                                                 Text  \
# 0  Four months after Twitter first introduced in-...
# 1  Posted \r\nTwitter will now allow people to ti...
# 2  Twitter will soon make Spaces even more promin...
# 3  The Fine Print: The following comments are own...
# 4  The Twitter app is seen on a smartphone in thi...
#
#                                               tokens
# 0  [four, month, twitter, first, introduced, inap...
# 1  [posted, twitter, allow, people, tip, favorite...
# 2  [twitter, soon, make, spaces, even, prominent,...
# 3  [fine, print, following, comment, owned, whoev...
# 4  [twitter, app, seen, smartphone, illustration,...

# %%
# Create a new tokens column for Ethereum

tokens =[]
for i in range(len(df_eth_sentiment)) :
    article_tokens = tokenizer(df_eth_sentiment["Text"][i])
    tokens.append(article_tokens)

df_eth_sentiment["tokens"] = tokens     
df_eth_sentiment.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0   -0.0516     0.128    0.778     0.094
# 1    0.0000     0.000    1.000     0.000
# 2    0.8402     0.000    0.714     0.286
# 3    0.7269     0.000    0.803     0.197
# 4    0.0000     0.000    1.000     0.000
#
#                                                 Text  \
# 0  crypto coins circle\r\nNurphoto\r\nThe smaller...
# 1  Paolo Ardoino was on the front lines of one of...
# 2  What happened\r\nPopular cryptocurrency Dogeco...
# 3  Starting next month, select users will begin t...
# 4  The personality behind the NFT Twitter account...
#
#                                               tokens
# 0  [crypto, coin, circlenurphotothe, smaller, cry...
# 1  [paolo, ardoino, wa, front, line, one, largest...
# 2  [happenedpopular, cryptocurrencydogecoincrypto...
# 3  [starting, next, month, select, user, begin, t...
# 4  [personality, behind, nft, twitter, account, c...

# %%
df_eth_sentiment["tokens"][1]
# Out:
# ['paolo',
#  'ardoino',
#  'wa',
#  'front',
#  'line',
#  'one',
#  'largest',
#  'cryptocurrency',
#  'heist',
#  'time',
#  'wa',
#  'flooded',
#  'call',
#  'message',
#  'august',
#  'alerting',
#  'breach',
#  'poly',
#  'network',
#  'platform',
#  'whe',
#  'char']

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# x = ' '.join(btc_news_articles)   joins all the articles
# y = tokenizer(x) 
# ngrams(y, n=2)
# can all be combined into one sentence below
btc_grams = Counter(ngrams(tokenizer(' '.join(btc_news_articles)), n=2)).most_common(30)
btc_grams
# Out:
# [(('char', 'twitter'), 18),
#  (('char', 'bitcoin'), 9),
#  (('bitcoin', 'btc'), 7),
#  (('content', 'creator'), 6),
#  (('social', 'medium'), 5),
#  (('twitter', 'ha'), 5),
#  (('tip', 'jar'), 4),
#  (('people', 'tip'), 4),
#  (('tip', 'favorite'), 4),
#  (('twitter', 'inc'), 4),
#  (('tip', 'bitcoin'), 4),
#  (('tipping', 'feature'), 4),
#  (('new', 'feature'), 4),
#  (('allow', 'people'), 3),
#  (('creator', 'bitcoin'), 3),
#  (('allow', 'user'), 3),
#  (('blog', 'post'), 3),
#  (('post', 'twitter'), 3),
#  (('able', 'tip'), 3),
#  (('adam', 'aron'), 3),
#  (('twitter', 'rolling'), 3),
#  (('nonfungible', 'token'), 3),
#  (('legal', 'tender'), 3),
#  (('tips', 'feature'), 3),
#  (('ha', 'announced'), 3),
#  (('digital', 'currency'), 3),
#  (('thursday', 'twitter'), 3),
#  (('char', 'beincrypto'), 3),
#  (('digital', 'asset'), 3),
#  (('bitcoin', 'ha'), 3)]

# %%
# Generate the Ethereum N-grams where N=2
# x = ' '.join(eth_news_articles)   joins all the articles
# y = tokenizer(x) 
# ngrams(y, n=2)
# can all be combined into one sentence below
eth_grams = Counter(ngrams(tokenizer(' '.join(eth_news_articles)), n=2)).most_common(30)
eth_grams
# Out:
# [(('sept', 'prnewswire'), 16),
#  (('protocol', 'labs'), 5),
#  (('digital', 'asset'), 5),
#  (('char', 'bitcoin'), 5),
#  (('announced', 'today'), 5),
#  (('social', 'medium'), 4),
#  (('crypto', 'wallet'), 4),
#  (('nonfungible', 'token'), 4),
#  (('china', 'sept'), 4),
#  (('char', 'ethereum'), 3),
#  (('polygon', 'ethereum'), 3),
#  (('ethereum', 'scaling'), 3),
#  (('scaling', 'platform'), 3),
#  (('platform', 'protocol'), 3),
#  (('char', 'crypto'), 3),
#  (('today', 'announced'), 3),
#  (('char', 'new'), 3),
#  (('lookup', 'user'), 3),
#  (('crypto', 'coin'), 2),
#  (('wa', 'flooded'), 2),
#  (('flooded', 'call'), 2),
#  (('call', 'message'), 2),
#  (('message', 'august'), 2),
#  (('august', 'alerting'), 2),
#  (('alerting', 'breach'), 2),
#  (('breach', 'poly'), 2),
#  (('poly', 'network'), 2),
#  (('network', 'platform'), 2),
#  (('adam', 'aron'), 2),
#  (('next', 'month'), 2)]

# %%
# Function token_count generates the top 10 words for a given coin
# I use Nvalue = 3 as the default if no value is passed
def token_count(articles, Nvalue = 3):
    """Returns the top N tokens from the frequency count"""
    
    # Combine all articles in corpus into one large string
    all_articles_joined = ' '.join(articles)
    processed = tokenizer(all_articles_joined)
  
    bigrams = ngrams(processed , n=Nvalue)
    top_10 = dict(Counter(bigrams).most_common(10))
   
    
    return top_10

# %%
# Use token_count to get the top 10 words for Bitcoin
top10_btc_words = token_count(btc_news_articles)
top10_btc_words
# Out:
# {('allow', 'people', 'tip'): 3,
#  ('people', 'tip', 'favorite'): 3,
#  ('content', 'creator', 'bitcoin'): 3,
#  ('blog', 'post', 'twitter'): 3,
#  ('char', 'twitter', 'ha'): 3,
#  ('twitter', 'ha', 'announced'): 3,
#  ('tip', 'jar', 'feature'): 2,
#  ('tip', 'favorite', 'content'): 2,
#  ('favorite', 'content', 'creator'): 2,
#  ('company', 'said', 'char'): 2}

# %%
# Use token_count to get the top 10 words for Ethereum

top10_eth_words = token_count(eth_news_articles)
top10_eth_words
# Out:
# {('china', 'sept', 'prnewswire'): 4,
#  ('polygon', 'ethereum', 'scaling'): 3,
#  ('ethereum', 'scaling', 'platform'): 3,
#  ('scaling', 'platform', 'protocol'): 3,
#  ('platform', 'protocol', 'labs'): 3,
#  ('wa', 'flooded', 'call'): 2,
#  ('flooded', 'call', 'message'): 2,
#  ('call', 'message', 'august'): 2,
#  ('message', 'august', 'alerting'): 2,
#  ('august', 'alerting', 'breach'): 2}

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_news_articles))
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(eth_news_articles))
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_articles_joined = ' '.join(btc_news_articles)

# %%
# Run the NER processor on all of the text
doc = nlp(all_articles_joined)


# Add a title to the document
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will now allow people to tip their favorite content creators with bitcoin and it will test new ways to help users have a safer experience on the social media app, the company said on… [+44 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will soon make Spaces even more prominent in its app as it looks to add more creator-focused tools to the live audio feature. The company says its working on making conversations in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spaces
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ea… [+1856 chars]
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Fine Print
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# : The following comments are owned by whoever posted them. We are not responsible for them in any way. The Twitter app is seen on a smartphone in this illustration taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 13, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic/Illustration/File
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  PhotoSept
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Twitter Inc (TWTR.N) will now allow people to tip their… [+1354 chars] Twitter will now allow content creators to receive tips in the form of bitcoin from their followers and will launch a fund for users who are leaders in the audio chat rooms in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spaces
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the company ann… [+2160 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paolo Ardoino
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was on the front lines of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the largest cryptocurrency heists of all time. He was flooded with calls and messages in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  alerting him to a breach at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poly Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>&lt;ul&gt;&lt;li&gt;At a recent press briefing,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  provided updates on several new initiatives aimed at helping creators, communities, and general users.&lt;/li&gt;&lt;li&gt;Recording and replays are c… [+3221 chars] DIVERSIFICATION IS BOTH observed and sensible; a rule of behaviour which does not imply the superiority of diversification must be rejected both as a hypothesis and as a maxim, wrote
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry Markowitz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,… [+4509 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>said it was rolli… [+1853 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robert Kiyosaki
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Rich Dad Channel/YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em;

# %%
# List all Entities
entities = [ent.text for ent in doc.ents]
entities
# Out:
# ['Four months',
#  'Twitter',
#  'Twitter',
#  'Spaces',
#  'The Fine Print',
#  'July 13, 2021',
#  'REUTERS',
#  'Dado Ruvic/Illustration/File',
#  '23',
#  'Reuters',
#  'Spaces',
#  'Paolo Ardoino',
#  'one',
#  'August',
#  'Poly Network',
#  'Twitter',
#  'Harry Markowitz',
#  'Twitter Inc.',
#  'Thursday',
#  'Robert Kiyosaki',
#  'The Rich Dad Channel/YouTube',
#  'Rich Dad Poor Dad',
#  'Robert Kiyosaki',
#  'Evergrande',
#  'US',
#  'Twitter',
#  'one',
#  'first',
#  'AMC',
#  'Adam Aron',
#  'Wednesday',
#  'Tuesday',
#  'Aron',
#  '178,000',
#  'Twitter',
#  'May',
#  'Twitter',
#  'Four thousand U.S. dollars',
#  'Westminster',
#  'Colorado',
#  'November 3, 2009',
#  'REUTERS',
#  'Rick Wilking/File PhotoNEW YORK',
#  'Sept 23',
#  'Reuters',
#  'Britain',
#  'Prudential Regulation',
#  'the Prudential Regulation Authority',
#  'Sam Woods',
#  "the Bank of England's",
#  'Twitter',
#  'Twitter',
#  'May',
#  'Adam Arons',
#  'Doge',
#  'Monday',
#  'Tuesday',
#  'AMC Theaters',
#  '0.5%',
#  'Norway',
#  'first',
#  'Iqbal Ahmed',
#  'Chuck Mikolajczak',
#  'NEW YORK',
#  'Sept 23',
#  'Reuters',
#  'next month',
#  'Robinhood',
#  'Robinhood',
#  'DOGE',
#  'yesterday',
#  'Adam Aron',
#  'AMC',
#  'Escape',
#  'Magenta',
#  'Blac',
#  'El Salvadors',
#  'Bitcoin',
#  'US',
#  'first',
#  'AMC Entertainment Holdings\xa0',
#  'NYSE',
#  'AMC',
#  'millions',
#  'Adam Aron',
#  'Twitter',
#  'today',
#  'Elon Musk',
#  'Telsa',
#  'Su',
#  '2021',
#  '2013',
#  '2021',
#  'this week',
#  'Tips',
#  'Twitter',
#  'Tip Jar',
#  'Polynesians',
#  'Kevin W',
#  'Coral Reef Protection in Exchange for Debt Relief',
#  'Credit Slips',
#  'the Deep Dive',
#  "Bitcoin Magazine's",
#  'first',
#  'Sept. 7',
#  'El Salvador',
#  'first',
#  'Twitter',
#  'Bitcoi',
#  'Earlier this month',
#  'El Salvador',
#  'Twitter',
#  'Twitter',
#  'eight',
#  'Bitcoin Bottom Line',
#  'Steven McClurg',
#  'C.J. Wilson',
#  'National Football League',
#  'the Deep Dive',
#  "Bitcoin Magazine's",
#  'first',
#  'Twitter Spaces',
#  '@2140data',
#  'Peter McCormack',
#  'September 10, 2021',
#  'Peter Schiff',
#  'Greg Foss',
#  'Thursday',
#  'Twitter',
#  'third',
#  'Strike',
#  'iOS',
#  'Bitc',
#  'BitMEX',
#  'two',
#  'Rene Pickhardt',
#  'Chris Coverdale',
#  '2021',
#  'Rene',
#  'Chris',
#  'Marty',
#  '1081',
#  'Dystopia watch',
#  'This weeks',
#  'Coinbase',
#  'this week',
#  'the month',
#  'Twitter',
#  'Tips',
#  'FDIC',
#  '0.04%',
#  'Twitter',
#  'Jack Dorsey',
#  'Apple',
#  'this year',
#  'August',
#  'OpenSea',
#  'NFT',
#  '$3.4 billion',
#  'BeInCrypto',
#  'NVT',
#  '+609',
#  'one-hour',
#  'Adorama',
#  'Sal D’Alia',
#  'Selangor',
#  'Comm Datuk Arjunaidi Mohamed',
#  'above $44,000',
#  'Thursday, Sept. 23',
#  'China',
#  'Evergrande',
#  'week',
#  '46 days',
#  '86%',
#  '$2 billion',
#  'September',
#  'Twitter',
#  '10%',
#  'earlier this week',
#  'Fed',
#  'Jerome Powell',
#  'yesterday',
#  'Fed',
#  'CBDC',
#  'Sept. 23',
#  'week',
#  'Bitcoin.org',
#  'one',
#  'first',
#  'Cobra',
#  'Bitcoin.orgs',
#  'Sept. 23',
#  'today',
#  'Bitcoi',
#  'Twitter',
#  'James Martin',
#  'Twitter',
#  'Thursday',
#  'Thursday',
#  'Twitter',
#  'Tips',
#  'Tweeters',
#  'the Lightning Network',
#  'BTC',
#  'this week',
#  'Glassnode',
#  'Universal Images Group',
#  'Getty Images\r\n',
#  'Africa',
#  'CoinGeek New York Event',
#  'Sheraton Hotel',
#  'Times Square',
#  'Oct 5-7, 2021',
#  'LONDON',
#  'Sept. 23, 2021',
#  'Thursday',
#  'TikTok',
#  'Digital',
#  'Twitter',
#  'NYSE',
#  'TWTR',
#  "Jack Dorsey's",
#  'first',
#  'two',
#  '1',
#  'Thursday',
#  'Twitter Inc',
#  'NYSE',
#  'TWTR',
#  'first',
#  'year',
#  'Twitter',
#  'Wednesday',
#  'Tips',
#  'this week',
#  'BeInCryptos Video News Show',
#  'Jessica Walker',
#  'two',
#  'Twitter',
#  'Sept. 23',
#  'Twitter',
#  'Nine',
#  'the Basel Committee on Banking Supervision (BCBS',
#  '10%',
#  'earlier this week',
#  'Twitter',
#  'May',
#  'Bitcoin.org',
#  'Thursday',
#  'morning',
#  'third',
#  'Thursday',
#  'Lightning Network',
#  'Cointelegraph',
#  'Benton Yaun',
#  'Jordan Finneseth',
#  'Heres',
#  'this weeks',
#  'Nervos',
#  'HANGZHOU',
#  'China',
#  'Sept. 23, 2021',
#  'today',
#  'BulletProofLinkwhich',
#  'Microsoft',
#  'NFT',
#  'Getty Images',
#  'Thursday',
#  'TikTok',
#  'This week',
#  'the Kaspersky Transatlantic Cable',
#  'Ahmed',
#  'Dave',
#  'American',
#  'seven',
#  'three',
#  'Kabul',
#  'last month',
#  'Crypto App',
#  'Ethereum',
#  'WIRE)--Mawson Infrastructure Group Inc.',
#  'Mawson',
#  'around $50,000',
#  'just $5402',
#  'Pyth Network',
#  'BTC/USD',
#  'a month',
#  'August',
#  'Twitter',
#  'Super Follows',
#  'monthly',
#  'between $3 and $10']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
all_articles_joined = ' '.join(eth_news_articles)

# %%
# Run the NER processor on all of the text
doc = nlp(all_articles_joined)

# Add a title to the document
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crypto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The smaller cryptocurrencies rallied sharply on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , enjoying a swell of risk appetite after some of the concerns around the debt crunch at
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  property compan… [+2367 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paolo Ardoino
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was on the front lines of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the largest cryptocurrency heists of all time. He was flooded with calls and messages in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  alerting him to a breach at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poly Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Popular cryptocurrency Dogecoin(CRYPTO:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOGE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) got a boost from a surprising source
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yesterday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Aron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , CEO of movie theater chain
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , shared on social media about his company's need … [+3893 chars] Starting
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , select users will begin testing crypto wallets on the popular financial services mobile app
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robinhood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robinhood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  crypto wallets will allow users to easily move supported… [+1371 chars] The personality behind the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  account
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     @CozomoMedici
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has officially been revealed. The account, which is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only about a month old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , has been known for documenting speculations on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     over 140
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# … [+1656 chars] In this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one-hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# -long documentary from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adorama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sal D’Alia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  covers the crypto movement with a series of interviews and information breakdowns to help educate viewers on the growing world of crypto-art… [+4569 chars] Everyone will soon be able to tip bitcoin on
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-he

# %%
# List all Entities
entities = [ent.text for ent in doc.ents]
entities
# Out:
# ['crypto',
#  'Thursday',
#  'Chinese',
#  'Paolo Ardoino',
#  'one',
#  'August',
#  'Poly Network',
#  'DOGE',
#  'yesterday',
#  'Adam Aron',
#  'AMC',
#  'next month',
#  'Robinhood',
#  'Robinhood',
#  'NFT',
#  'Twitter',
#  '@CozomoMedici',
#  'only about a month old',
#  'over 140',
#  'one-hour',
#  'Adorama',
#  'Sal D’Alia',
#  'Twitter',
#  'one',
#  'first',
#  'Adam Arons',
#  'Doge',
#  'Monday',
#  'Tuesday',
#  'AMC Theaters',
#  'first',
#  'this year',
#  'August',
#  'OpenSea',
#  'NFT',
#  '$3.4 billion',
#  '2.0',
#  '2.0',
#  'DeFi',
#  'SINGAPORE',
#  'Sept. 23, 2021',
#  'The9',
#  'Polygon',
#  'Ethereum',
#  'Protocol Labs, Inc.',
#  'Protocol Labs',
#  'AMC Entertainment Holdings\xa0',
#  'NYSE',
#  'AMC',
#  'millions',
#  'Adam Aron',
#  'Elon Musk',
#  'Telsa',
#  'Su',
#  'first',
#  'Avalanche',
#  'February',
#  'as high as $60',
#  'JuneJuly',
#  'one',
#  '3lau',
#  'Worst Case',
#  'October 8th',
#  '50 percent',
#  '333',
#  'DJ',
#  'Va.',
#  'Sept. 23, 2021',
#  'GLOBE NEWSWIRE',
#  'SYSX',
#  'Bitfinex',
#  'today',
#  'DeversiFi',
#  'NFT',
#  'Getty Images',
#  'above $3,000',
#  'Sept. 23',
#  'CryptoQuant',
#  'Digital',
#  'Twitter',
#  'NYSE',
#  'TWTR',
#  "Jack Dorsey's",
#  'first',
#  'above $3,000',
#  'US',
#  '3,200',
#  'Nervos',
#  'HANGZHOU',
#  'China',
#  'Sept. 23, 2021',
#  'today',
#  'NFT',
#  'MusicFund',
#  'Early 2021',
#  'Ethereum',
#  'Polish',
#  'Robert Lewandowski',
#  'Lovetsky-Pool/Getty Images',
#  'this weeks',
#  'SportsMoney',
#  'Playbook',
#  'NBA Top Shot',
#  'NASDAQ',
#  'Polygon',
#  'Ethereum',
#  'Protocol Labs',
#  'Non-Fungible Token',
#  'Airdrop',
#  'FOX',
#  '13',
#  'DAO',
#  'DENVER',
#  'Sept. 23, 2021',
#  'HONG KONG',
#  'Sept. 23, 2021',
#  'GLOBE NEWSWIRE',
#  'De-Fi',
#  'FDIC',
#  '0.04%',
#  'Today',
#  'SEC',
#  'Clayton',
#  'SEC',
#  'two',
#  'SEC',
#  'Clayton',
#  'SEC',
#  'two',
#  'Blockdaemon',
#  '$155 million',
#  'today',
#  'Bitcoi',
#  'CAMBRIDGE',
#  'Mass.',
#  'Sept. 23, 2021',
#  "MIT Technology Review's",
#  'annual',
#  'Crypto App',
#  'Ethereum',
#  'the Monetary Authority of Singapore',
#  '+2332',
#  'August',
#  'Poly Network',
#  'Ethereum',
#  '+211',
#  'two',
#  '1',
#  'Acceso',
#  'Mark Cuban',
#  'DeFi',
#  'Berlin Exchange',
#  'TradeGate',
#  'VANCOUVER',
#  'BC',
#  'Sept. 23, 2021',
#  '/PRNewswire/ - LUXXFOLIO Holdings Inc.',
#  'CSE',
#  'Frankfurt',
#  'LUH',
#  'Berlin',
#  'Financial Advisors, Asset Managers Served',
#  'Retirement Accounts',
#  'SAN FRANCISCO',
#  'Sept. 23, 2021',
#  'almost a week',
#  'Thursday, September 23',
#  '4.41 percent',
#  'Ind',
#  '500',
#  '1-3 days',
#  'first',
#  'June',
#  'FOMC',
#  'existence w',
#  'GRAND CAYMAN',
#  'Cayman Islands',
#  'Sept. 23, 2021',
#  'today',
#  'Lucidity',
#  'GPU',
#  'The Full Henry Singleton Series',
#  'PDF',
#  '4',
#  '500',
#  'Oregon',
#  'Kayvon Thibodeaux',
#  'Ducks',
#  'Thursday',
#  'this year',
#  'Australian',
#  'Sydney',
#  'Blockchain',
#  'SaTT',
#  'first',
#  'MVP',
#  '2020',
#  'France',
#  'Atayen Inc.',
#  'China',
#  'Chinese',
#  'two',
#  '5-day',
#  '7%',
#  'the past 24 hours',
#  'One',
#  '43,592',
#  '10%',
#  '1 week ago',
#  'Jordan Mansfield',
#  'the last quarter',
#  'Voyager D',
#  'New Delhi',
#  'Thursday',
#  'the past few days',
#  'This week',
#  '10,000',
#  'Chinese',
#  'Evergrande',
#  '$83.5 million',
#  'today',
#  '$300 billion',
#  'Strike\r\nPeople',
#  'Twitter',
#  'Twitter',
#  'Bit',
#  'Mike Novogratz',
#  'one',
#  'Photo',
#  'John Lamparski',
#  'Mike Novogratz',
#  '40,000',
#  'ZHUHAI',
#  'China',
#  'Sept. 23, 2021',
#  'Powerbridge Technologies Co., Ltd.',
#  'Nasdaq: PBTS',
#  'Powerbridge',
#  'Blockchain',
#  'Michael Bisping',
#  'Photo',
#  'Jeff Bottari',
#  'Zuffa',
#  'LLC',
#  'Michael Bisping',
#  '2013',
#  'Switzerland',
#  'Sept. 23, 2021',
#  'Thorg',
#  'More than a decade',
#  'the years',
#  'Twitter',
#  'Tips',
#  'First',
#  'May',
#  'US',
#  'Tips',
#  'SINGAPORE',
#  'Sept. 23, 2021',
#  'The9',
#  'Polygon',
#  'Ethereum',
#  'Protocol Labs, Inc.',
#  'Protocol Labs',
#  'Crypto',
#  'this morning',
#  'the last 24 hours',
#  '44k',
#  'CAMBRIDGE',
#  'Mass.',
#  'Sept. 23, 2021',
#  "MIT Technology Review's",
#  'annual',
#  'September 28-30, 2021',
#  '+3736',
#  'HANGZHOU',
#  'China',
#  'Sept. 23, 2021',
#  'today',
#  'Covalent\r\n',
#  'Filecoin\r\n\xa0',
#  'the Filecoin Network',
#  'the Filecoin Network',
#  'Chloe',
#  'thousands of dollars',
#  'Chloe Clem',
#  'Getty Images',
#  'the past year',
#  'Ethereum',
#  'DENVER',
#  'Sept. 23, 2021',
#  'today',
#  'Decentralized Autonomous Organization',
#  'DAO',
#  'second',
#  'WENZHOU',
#  'China',
#  'Sept. 23, 2021',
#  'ZK International Group Co.',
#  'xSigma Collectibles Limited',
#  'The Fine Print',
#  'Robinhood Markets, Inc.',
#  'nearly 11%',
#  'Wednesday',
#  'next month',
#  'SAN FRANCISCO',
#  'Sept. 23, 2021',
#  'today',
#  'GRAND CAYMAN',
#  'Cayman Islands',
#  'Sept. 23, 2021',
#  'today',
#  'Lucidity',
#  'IDX',
#  'FAQ',
#  'Ethereum',
#  'Twitter',
#  'The Best Guide To Showcase IDX Reviews &amp',
#  'Product Details',
#  'Ethereum',
#  'Twitter',
#  'Berlin Exchange',
#  'TradeGate',
#  'VANCOUVER',
#  'BC',
#  'Sept. 23, 2021',
#  '/PRNewswire/ - LUXXFOLIO Holdings Inc.',
#  'CSE',
#  'Frankfurt',
#  'LUH',
#  'Berlin',
#  'turkey',
#  'Tracks der Musikvideo-Posts',
#  'Neue Tracks',
#  '5',
#  'November',
#  'Chinese',
#  'Evergrande',
#  '$83.5 million',
#  'today',
#  '$300 billion',
#  'Today',
#  '2009',
#  'Satoshi Nakamoto',
#  'Today',
#  "Crypto Whale 'Confirms'",
#  '10',
#  'Twitter',
#  'the next two months',
#  '+3617',
#  'NFT',
#  'September 23',
#  '10,000']

# %% [markdown]
# ---
